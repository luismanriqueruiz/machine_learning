# %%
texts = [
    "ру́сский язы́к", # Russian
    "中文",           # Chinese
    "にほんご",      # Japanese
    "العَرَبِيَّة"  # Arabic
]

# %% [markdown]
# ## Testing packages
#
# ### Langdetect library

# %%
from langdetect import detect

# %%
for text in texts:
    print(detect(text))
# Out:
# ru
# zh-cn
# ja
# ar

# %% [markdown]
# ### Pycld2 library

# %%
import pycld2 as cld2

# %%
for text in texts:
    isReliable, textBytesFound, details = cld2.detect(text)
    print(details)
# Out:
# (('Unknown', 'un', 0, 0.0), ('Unknown', 'un', 0, 0.0), ('Unknown', 'un', 0, 0.0))
# (('ChineseT', 'zh-Hant', 87, 1755.0), ('Unknown', 'un', 0, 0.0), ('Unknown', 'un', 0, 0.0))
# (('Japanese', 'ja', 92, 3859.0), ('Unknown', 'un', 0, 0.0), ('Unknown', 'un', 0, 0.0))
# (('Unknown', 'un', 0, 0.0), ('Unknown', 'un', 0, 0.0), ('Unknown', 'un', 0, 0.0))

# %%
def lang_detected(text):
    isReliable, textBytesFound, details = cld2.detect(text)
    return(details[0])

# %%
print(lang_detected("にほんご"))
# Out:
# ('Japanese', 'ja', 92, 3859.0)

# %% [markdown]
# ## Testing NER
#
# ### Part 1
#
# [Xlm roberta ner Japanese](https://huggingface.co/tsmatz/xlm-roberta-ner-japanese)

# %%
from transformers import pipeline

# %%
from pprint import pprint

# %%
text = "鈴井は4月の陽気の良い日に、鈴をつけて北海道のトムラウシへと登った"

# %%
model_name = "tsmatz/xlm-roberta-ner-japanese"
classifier = pipeline("token-classification", model=model_name)
result = classifier(text)
# Out:
# /home/luis-carlos/anaconda3/envs/zanalytics/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
pprint(result)
# Out:
# [{'end': 1,
#   'entity': 'PER',
#   'index': 1,
#   'score': 0.9992749,
#   'start': 0,
#   'word': '▁'},
#  {'end': 1,
#   'entity': 'PER',
#   'index': 2,
#   'score': 0.9993655,
#   'start': 0,
#   'word': '鈴'},
#  {'end': 2,
#   'entity': 'PER',
#   'index': 3,
#   'score': 0.9992323,
#   'start': 1,
#   'word': '井'},
#  {'end': 22,
#   'entity': 'LOC',
#   'index': 14,
#   'score': 0.99775296,
#   'start': 19,
#   'word': '北海道'},
#  {'end': 24,
#   'entity': 'LOC',
#   'index': 16,
#   'score': 0.9978789,
#   'start': 23,
#   'word': 'ト'},
#  {'end': 25,
#   'entity': 'LOC',
#   'index': 17,
#   'score': 0.9983669,
#   'start': 24,
#   'word': 'ム'},
#  {'end': 26,
#   'entity': 'LOC',
#   'index': 18,
#   'score': 0.9983725,
#   'start': 25,
#   'word': 'ラ'},
#  {'end': 27,
#   'entity': 'LOC',
#   'index': 19,
#   'score': 0.9978707,
#   'start': 26,
#   'word': 'ウ'},
#  {'end': 28,
#   'entity': 'LOC',
#   'index': 20,
#   'score': 0.9982278,
#   'start': 27,
#   'word': 'シ'}]

# %% [markdown]
# ### Part 2

# %%
ner_pipeline = pipeline(
    model="llm-book/bert-base-japanese-v3-ner-wikipedia-dataset",
    aggregation_strategy="simple",
)

# %%
pprint(ner_pipeline(text))
# Out:
# [{'end': None,
#   'entity_group': '人名',
#   'score': 0.9969324,
#   'start': None,
#   'word': '鈴井'},
#  {'end': None,
#   'entity_group': '地名',
#   'score': 0.99784124,
#   'start': None,
#   'word': '北海道'},
#  {'end': None,
#   'entity_group': '地名',
#   'score': 0.99032897,
#   'start': None,
#   'word': 'トムラウシ'}]

# %% [markdown]
# ### Part 3

# %%
import nagisa

# %%
text = 'Pythonで簡単に使えるツールです'
words = nagisa.tagging(text)
print(words)
#=> Python/名詞 で/助詞 簡単/形状詞 に/助動詞 使える/動詞 ツール/名詞 です/助動詞
# Out:
# Python/名詞 で/助詞 簡単/形状詞 に/助動詞 使える/動詞 ツール/名詞 です/助動詞

# %%
# Get a list of words
print(words.words)
#=> ['Python', 'で', '簡単', 'に', '使える', 'ツール', 'です']
# Out:
# ['Python', 'で', '簡単', 'に', '使える', 'ツール', 'です']

# %%
# Get a list of POS-tags
print(words.postags)
# Out:
# ['名詞', '助詞', '形状詞', '助動詞', '動詞', '名詞', '助動詞']

# %%
def ner_jp_nagisa(text):
    words = nagisa.tagging(text)
    return(words.words, words.postags)

# %%
print(ner_jp_nagisa('Pythonで簡単に使えるツールです'))
# Out:
# (['Python', 'で', '簡単', 'に', '使える', 'ツール', 'です'], ['名詞', '助詞', '形状詞', '助動詞', '動詞', '名詞', '助動詞'])

# %% [markdown]
# ## Loading data
#
# ### Example 1

# %%
path = '/home/luis-carlos/Documents/experiments/nlp/data/example_zeals.csv'

# %%
import pandas as pd

# %%
data = pd.read_csv(path)
data.head(10)
# Out:
#                prev_message
# 0                男性にも使えますか？
# 1  なるほど、男性におすすめのアイテム教えてください
# 2                乾燥に効きそうなやつ
# 3      えっ？kinuiって保湿クリームあるの？
# 4                       1枚目
# 5                       1枚目
# 6          おすすめの使用方法はありますか？
# 7            どうやって購入するんですか？
# 8                     ありがとう
# 9                   俺の肌状態は？

# %%
for index, row in data.iterrows():
    text = row['prev_message']
    pprint(text)

    # Inferring language
    isReliable, textBytesFound, details = cld2.detect(text)
    pprint(details[0][0])

    #pprint(ner_pipeline(text))
    #result = classifier(text)
    #pprint(result)

    # Starting NER
    words = nagisa.tagging(text)
    print(words.words)
    print(words.postags)

    print('--------------------------------\n')
# Out:
# '男性にも使えますか？'
# 'Japanese'
# ['男性', 'に', 'も', '使え', 'ます', 'か', '?']
# ['名詞', '助詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'なるほど、男性におすすめのアイテム教えてください'
# 'Japanese'
# ['なるほど', '、', '男性', 'に', 'お', 'すすめ', 'の', 'アイテム', '教え', 'て', 'ください']
# ['副詞', '補助記号', '名詞', '助詞', '接頭辞', '動詞', '助詞', '名詞', '動詞', '助詞', '動詞']
# --------------------------------
#
# '乾燥に効きそうなやつ'
# 'Japanese'
# ['乾燥', 'に', '効き', 'そう', 'な', 'やつ']
# ['名詞', '助詞', '動詞', '形状詞', '助動詞', '名詞']
# --------------------------------
#
# 'えっ？kinuiって保湿クリームあるの？'
# 'Japanese'
# ['えっ', '?', 'kinui', 'って', '保湿', 'クリーム', 'ある', 'の', '?']
# ['感動詞', '補助記号', '名詞', '助詞', '名詞', '名詞', '動詞', '助詞', '補助記号']
# --------------------------------
#
# '1枚目'
# 'Unknown'
# ['1', '枚', '目']
# ['名詞', '接尾辞', '接尾辞']
# --------------------------------
#
# '1枚目'
# 'Unknown'
# ['1', '枚', '目']
# ['名詞', '接尾辞', '接尾辞']
# --------------------------------
#
# 'おすすめの使用方法はありますか？'
# 'Japanese'
# ['お', 'すすめ', 'の', '使用', '方法', 'は', 'あり', 'ます', 'か', '?']
# ['接頭辞', '動詞', '助詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'どうやって購入するんですか？'
# 'Japanese'
# ['どう', 'やっ', 'て', '購入', 'する', 'ん', 'です', 'か', '?']
# ['副詞', '動詞', '助詞', '名詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ありがとう'
# 'Japanese'
# ['ありがとう']
# ['感動詞']
# --------------------------------
#
# '俺の肌状態は？'
# 'Japanese'
# ['俺', 'の', '肌', '状態', 'は', '?']
# ['代名詞', '助詞', '名詞', '名詞', '助詞', '補助記号']
# --------------------------------
#
# '値段はいくら？'
# 'Japanese'
# ['値段', 'は', 'いくら', '?']
# ['名詞', '助詞', '名詞', '補助記号']
# --------------------------------
#
# '病気は治る？'
# 'Japanese'
# ['病気', 'は', '治る', '?']
# ['名詞', '助詞', '動詞', '補助記号']
# --------------------------------
#
# 'ニキビに効きますか？'
# 'Japanese'
# ['ニキビ', 'に', '効き', 'ます', 'か', '?']
# ['名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '私はピュアとリッチのどちらが良いですか？'
# 'Japanese'
# ['私', 'は', 'ピュア', 'と', 'リッチ', 'の', 'どちら', 'が', '良い', 'です', 'か', '?']
# ['代名詞', '助詞', '名詞', '助詞', '形状詞', '助詞', '代名詞', '助詞', '形容詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'にきく'
# 'Japanese'
# ['に', 'きく']
# ['助詞', '動詞']
# --------------------------------
#
# 'テスト'
# 'Japanese'
# ['テスト']
# ['名詞']
# --------------------------------
#
# 'アトピーに効きますか？'
# 'Japanese'
# ['アトピー', 'に', '効き', 'ます', 'か', '?']
# ['名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'こんにちは'
# 'Japanese'
# ['こんにちは']
# ['感動詞']
# --------------------------------
#
# '2'
# 'Unknown'
# ['2']
# ['名詞']
# --------------------------------
#
# '1'
# 'Unknown'
# ['1']
# ['名詞']
# --------------------------------
#
# '1'
# 'Unknown'
# ['1']
# ['名詞']
# --------------------------------
#
# '1'
# 'Unknown'
# ['1']
# ['名詞']
# --------------------------------
#
# 'たいせいありがとう！'
# 'Japanese'
# ['たいせい', 'ありがとう', '!']
# ['web誤脱', '感動詞', '補助記号']
# --------------------------------
#
# '本当に効くの？'
# 'Japanese'
# ['本当', 'に', '効く', 'の', '?']
# ['名詞', '助詞', '動詞', '助詞', '補助記号']
# --------------------------------
#
# '2'
# 'Unknown'
# ['2']
# ['名詞']
# --------------------------------
#
# '注文できてますか？'
# 'Japanese'
# ['注文', 'でき', 'て', 'ます', 'か', '?']
# ['名詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ニキビに効果はありますか？'
# 'Japanese'
# ['ニキビ', 'に', '効果', 'は', 'あり', 'ます', 'か', '?']
# ['名詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '解約'
# 'Unknown'
# ['解約']
# ['名詞']
# --------------------------------
#
# '今回の注文は合計何円ですか？'
# 'Japanese'
# ['今回', 'の', '注文', 'は', '合計', '何', '円', 'です', 'か', '?']
# ['名詞', '助詞', '名詞', '助詞', '名詞', '名詞', '名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'アトピーにもきくの？'
# 'Japanese'
# ['アトピー', 'に', 'も', 'きく', 'の', '?']
# ['名詞', '助詞', '助詞', '動詞', '助詞', '補助記号']
# --------------------------------
#
# '定期購入しないといけない？'
# 'Japanese'
# ['定期', '購入', 'し', 'ない', 'と', 'いけ', 'ない', '?']
# ['名詞', '名詞', '動詞', '助動詞', '助詞', '動詞', '助動詞', '補助記号']
# --------------------------------
#
# '定期の解約をお願いできますでしょうか？\n\n菅野理沙\n東京都練馬区'
# 'Japanese'
# ['定期', 'の', '解約', 'を', 'お', '願い', 'でき', 'ます', 'でしょう', 'か', '?', '\n', '\n', '菅野', '理沙', '\n', '東京', '都', '練馬', '区']
# ['名詞', '助詞', '名詞', '助詞', '接頭辞', '動詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号', '補助記号', '補助記号', '名詞', '名詞', '補助記号', '名詞', '名詞', '名詞', '名詞']
# --------------------------------
#
# '解約したい'
# 'Japanese'
# ['解約', 'し', 'たい']
# ['名詞', '動詞', '助動詞']
# --------------------------------
#
# '解約方法'
# 'Japanese'
# ['解約', '方法']
# ['名詞', '名詞']
# --------------------------------
#
# 'アトピーでも聞きますか？'
# 'Japanese'
# ['アトピー', 'で', 'も', '聞き', 'ます', 'か', '?']
# ['名詞', '助詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'はい'
# 'Unknown'
# ['はい']
# ['感動詞']
# --------------------------------
#
# '退会方法'
# 'Japanese'
# ['退会', '方法']
# ['名詞', '名詞']
# --------------------------------
#
# '2'
# 'Unknown'
# ['2']
# ['名詞']
# --------------------------------
#
# '肌が乾燥します'
# 'Japanese'
# ['肌', 'が', '乾燥', 'し', 'ます']
# ['名詞', '助詞', '名詞', '動詞', '助動詞']
# --------------------------------
#
# '肌が乾燥してて困ってます'
# 'Japanese'
# ['肌', 'が', '乾燥', 'し', 'て', 'て', '困っ', 'て', 'ます']
# ['名詞', '助詞', '名詞', '動詞', '助動詞', '助詞', '動詞', '助動詞', '助動詞']
# --------------------------------
#
# 'いくらですか？'
# 'Japanese'
# ['いくら', 'です', 'か', '?']
# ['名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '毛穴にも課題あります'
# 'Japanese'
# ['毛穴', 'に', 'も', '課題', 'あり', 'ます']
# ['名詞', '助詞', '助詞', '名詞', '動詞', '助動詞']
# --------------------------------
#
# '他の商品はあるの？'
# 'Japanese'
# ['他', 'の', '商品', 'は', 'ある', 'の', '?']
# ['名詞', '助詞', '名詞', '助詞', '動詞', '助詞', '補助記号']
# --------------------------------
#
# '契約解除したいです。🥺'
# 'Japanese'
# ['契約', '解除', 'し', 'たい', 'です', '。', '🥺']
# ['名詞', '名詞', '動詞', '助動詞', '助動詞', '補助記号', '補助記号']
# --------------------------------
#
# '電話したら契約解除できますか！'
# 'Japanese'
# ['電話', 'し', 'たら', '契約', '解除', 'でき', 'ます', 'か', '!']
# ['名詞', '動詞', '助動詞', '名詞', '名詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '電話番号おしえてほしいです'
# 'Japanese'
# ['電話', '番号', 'おしえ', 'て', 'ほしい', 'です']
# ['名詞', '名詞', '動詞', '助詞', '形容詞', '助動詞']
# --------------------------------
#
# 'オルビスについて教えて'
# 'Japanese'
# ['オルビス', 'に', 'つい', 'て', '教え', 'て']
# ['名詞', '助詞', '動詞', '助詞', '動詞', '助詞']
# --------------------------------
#
# 'Kinuiは脂性肌にもあいますか？'
# 'Japanese'
# ['Kinui', 'は', '脂性', '肌', 'に', 'も', 'あい', 'ます', 'か', '?']
# ['名詞', '助詞', '名詞', '名詞', '助詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ニキビにも効きますか？'
# 'Japanese'
# ['ニキビ', 'に', 'も', '効き', 'ます', 'か', '?']
# ['名詞', '助詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'どれくらいで効果を実感できますか？'
# 'Japanese'
# ['どれ', 'くらい', 'で', '効果', 'を', '実感', 'でき', 'ます', 'か', '?']
# ['代名詞', '助詞', '助詞', '名詞', '助詞', '名詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '使い方'
# 'Japanese'
# ['使い', '方']
# ['動詞', '接尾辞']
# --------------------------------
#
# 'https://kinui.tokyo/lp?u=otgm-lis_kinui-pure-oil&gad_source=1&gbraid=0AAAAApyzJpoGYeRnaBuLCyhg939AyRy39&gclid=Cj0KCQiA1Km7BhC9ARIsAFZfEItvtSXS_BUWuQ_S8Myrez2CO-UnzJhYjk0Y2aS5V_1-fVAL7bPv1_IaArbcEALw_wcB'
# 'Unknown'
# ['https://kinui.tokyo/lp?u=otgm-lis_kinui-pure-oil&gad_source=1&gbraid=0AAAAApyzJpoGYeRnaBuLCyhg939AyRy39&gclid=Cj0KCQiA1Km7BhC9ARIsAFZfEItvtSXS_BUWuQ_S8Myrez2CO-UnzJhYjk0Y2aS5V_1-fVAL7bPv1_IaArbcEALw_wcB']
# ['URL']
# --------------------------------
#
# 'https://www.google.co.jp/search?q=Google&client=safari&sca_esv=6dc60e3209c5ccf9&channel=iphone_bm&sxsrf=ADLYWIJ6E5uIYLzOrFYycvpLe-bXKR8kEg%3A1735047145861&source=hp&ei=6bdqZ5iwMMWP2roPhOan-AY&oq=Google&gs_lp=&sclient=mobile-gws-wiz-hp'
# 'Unknown'
# ['https://www.google.co.jp/search?q=Google&client=safari&sca_esv=6dc60e3209c5ccf9&channel=iphone_bm&sxsrf=ADLYWIJ6E5uIYLzOrFYycvpLe-bXKR8kEg%3A1735047145861&source=hp&ei=6bdqZ5iwMMWP2roPhOan-AY&oq=Google&gs_lp=&sclient=mobile-gws-wiz-hp']
# ['URL']
# --------------------------------
#
# 'https://www.google.co.jp/'
# 'Unknown'
# ['https://www.google.co.jp/']
# ['URL']
# --------------------------------
#
# 'https://www.orbis.co.jp/?pcd=20001141&plnkcd=426060&pmcd=j07&pmsegcd=45&pagtcd=7&pcdflg=1&utm_source=listing&utm_medium=google&utm_campaign=o_google_all_999_non_top_2105&utm_content=paid&saf_src=google_g&saf_pt=&saf_kw=%E3%82%AA%E3%83%AB%E3%83%93%E3%82%B9&saf_dv=&saf_cam=11867449582&saf_grp=114576615559&saf_ad=521292998328&account_id=5164243614&saf_acc=5164243614&saf_cam_tp=search&gad_source=1&gbraid=0AAAAADqiRbxzmvPaVDG1yIOF1j-FxQHCb&gclid=Cj0KCQiA1Km7BhC9ARIsAFZfEIvENoxJPupZ9yqWUDxLOEiI5zT7-Q-IDupF0i0cyLgPjEn4oAV3650aAt7jEALw_wcB'
# 'Unknown'
# ['https://www.orbis.co.jp/?pcd=20001141&plnkcd=426060&pmcd=j07&pmsegcd=45&pagtcd=7&pcdflg=1&utm_source=listing&utm_medium=google&utm_campaign=o_google_all_999_non_top_2105&utm_content=paid&saf_src=google_g&saf_pt=&saf_kw=%E3%82%AA%E3%83%AB%E3%83%93%E3%82%B9&saf_dv=&saf_cam=11867449582&saf_grp=114576615559&saf_ad=521292998328&account_id=5164243614&saf_acc=5164243614&saf_cam_tp=search&gad_source=1&gbraid=0AAAAADqiRbxzmvPaVDG1yIOF1j-FxQHCb&gclid=Cj0KCQiA1Km7BhC9ARIsAFZfEIvENoxJPupZ9yqWUDxLOEiI5zT7-Q-IDupF0i0cyLgPjEn4oAV3650aAt7jEALw_wcB']
# ['URL']
# --------------------------------
#
# '契約解除なってますか？'
# 'Japanese'
# ['契約', '解除', 'なっ', 'て', 'ます', 'か', '?']
# ['名詞', '名詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ありがとうございます'
# 'Japanese'
# ['ありがとう', 'ござい', 'ます']
# ['感動詞', '動詞', '助動詞']
# --------------------------------
#
# 'すみません。KINUIの注文をしたのですが、それをキャンセルってできますか💦'
# 'Japanese'
# ['すみ', 'ませ', 'ん', '。', 'KINUI', 'の', '注文', 'を', 'し', 'た', 'の', 'です', 'が', '、', 'それ', 'を', 'キャンセル', 'って', 'でき', 'ます', 'か', '💦']
# ['動詞', '助動詞', '助動詞', '補助記号', '名詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号', '代名詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '解約したい'
# 'Japanese'
# ['解約', 'し', 'たい']
# ['名詞', '動詞', '助動詞']
# --------------------------------
#
# 'あはははは'
# 'Japanese'
# ['あはははは']
# ['感動詞']
# --------------------------------
#
# '間違って注文を二回してしまったようでエラーになるのですが、一回は注文できてますでしょうか？'
# 'Japanese'
# ['間違っ', 'て', '注文', 'を', '二', '回', 'し', 'て', 'しまっ', 'た', 'よう', 'で', 'エラー', 'に', 'なる', 'の', 'です', 'が', '、', '一', '回', 'は', '注文', 'でき', 'て', 'ます', 'でしょう', 'か', '?']
# ['動詞', '助詞', '名詞', '助詞', '名詞', '名詞', '動詞', '助詞', '動詞', '助動詞', '形状詞', '助動詞', '名詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号', '名詞', '名詞', '助詞', '名詞', '動詞', '助動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '1'
# 'Unknown'
# ['1']
# ['名詞']
# --------------------------------
#
# 'どんな効果がある？'
# 'Japanese'
# ['どんな', '効果', 'が', 'ある', '?']
# ['連体詞', '名詞', '助詞', '動詞', '補助記号']
# --------------------------------
#
# 'どんな人におすすめ？'
# 'Japanese'
# ['どんな', '人', 'に', 'お', 'すすめ', '?']
# ['連体詞', '名詞', '助詞', '接頭辞', '動詞', '補助記号']
# --------------------------------
#
# '中学生が使って大丈夫？'
# 'Japanese'
# ['中学', '生', 'が', '使っ', 'て', '大丈夫', '?']
# ['名詞', '接尾辞', '助詞', '動詞', '助詞', '形状詞', '補助記号']
# --------------------------------
#
# '29歳でもすすめ？'
# 'Japanese'
# ['2', '9', '歳', 'で', 'も', 'すすめ', '?']
# ['名詞', '名詞', '接尾辞', '助詞', '助詞', '動詞', '補助記号']
# --------------------------------
#
# '何歳におすすめ？'
# 'Japanese'
# ['何', '歳', 'に', 'お', 'すすめ', '?']
# ['名詞', '接尾辞', '助詞', '接頭辞', '動詞', '補助記号']
# --------------------------------
#
# 'あああああ'
# 'Japanese'
# ['ああ', 'あ', 'ああ']
# ['感動詞', '感動詞', '感動詞']
# --------------------------------
#
# 'どんなせいぶん？'
# 'Japanese'
# ['どんな', 'せい', 'ぶん', '?']
# ['連体詞', '動詞', '名詞', '補助記号']
# --------------------------------
#
# '成分は？'
# 'Japanese'
# ['成分', 'は', '?']
# ['名詞', '助詞', '補助記号']
# --------------------------------
#
# 'こんにちは'
# 'Japanese'
# ['こんにちは']
# ['感動詞']
# --------------------------------
#
# '仲良くなりましょ'
# 'Japanese'
# ['仲良く', 'なり', 'ましょ']
# ['副詞', '動詞', '助動詞']
# --------------------------------
#
# '配達状況'
# 'Japanese'
# ['配達', '状況']
# ['名詞', '名詞']
# --------------------------------
#
# 'キヌユイは化粧水ですか？'
# 'Japanese'
# ['キヌユイ', 'は', '化粧', '水', 'です', 'か', '?']
# ['名詞', '助詞', '名詞', '接尾辞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'キヌユイの乳液はありますか'
# 'Japanese'
# ['キヌユイ', 'の', '乳液', 'は', 'あり', 'ます', 'か']
# ['名詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞']
# --------------------------------
#
# '一回だけ買う場合の値段はどうなりますか'
# 'Japanese'
# ['一', '回', 'だけ', '買う', '場合', 'の', '値段', 'は', 'どう', 'なり', 'ます', 'か']
# ['名詞', '名詞', '助詞', '動詞', '名詞', '助詞', '名詞', '助詞', '副詞', '動詞', '助動詞', '助詞']
# --------------------------------
#
# '脂性肌には良くないって聞いたんだけど良くない？'
# 'Japanese'
# ['脂性', '肌', 'に', 'は', '良く', 'ない', 'って', '聞い', 'た', 'ん', 'だ', 'けど', '良く', 'ない', '?']
# ['名詞', '名詞', '助詞', '助詞', '形容詞', '形容詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '形容詞', '形容詞', '補助記号']
# --------------------------------
#
# '初回限定の1.980円で買うと定期縛りはないんですか？'
# 'Japanese'
# ['初回', '限定', 'の', '1', '.', '9', '8', '0', '円', 'で', '買う', 'と', '定期', '縛り', 'は', 'ない', 'ん', 'です', 'か', '?']
# ['名詞', '名詞', '助詞', '名詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助詞', '動詞', '助詞', '名詞', '名詞', '助詞', '形容詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '初回限定では無いところで買うと定期縛りはありますか？'
# 'Japanese'
# ['初回', '限定', 'で', 'は', '無い', 'ところ', 'で', '買う', 'と', '定期', '縛り', 'は', 'あり', 'ます', 'か', '?']
# ['名詞', '名詞', '助動詞', '助詞', '形容詞', '名詞', '助詞', '動詞', '助詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '定期購入の縛りは無いのになぜ解約というものがあるのですか？'
# 'Japanese'
# ['定期', '購入', 'の', '縛り', 'は', '無い', 'の', 'に', 'なぜ', '解約', 'と', 'いう', 'もの', 'が', 'ある', 'の', 'です', 'か', '?']
# ['名詞', '名詞', '助詞', '名詞', '助詞', '形容詞', '助詞', '助詞', '副詞', '名詞', '助詞', '動詞', '名詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '理解しました‼️ありがとうございます😊'
# 'Japanese'
# ['理解', 'し', 'まし', 'た', '!', '!', '️', 'ありがとう', 'ござい', 'ます', '😊']
# ['名詞', '動詞', '助動詞', '助動詞', '補助記号', '補助記号', '補助記号', '感動詞', '動詞', '助動詞', '補助記号']
# --------------------------------
#
# 'キヌユイを買うと必ず定期縛りになりますか？それとも自分で定期購入するのですか？'
# 'Japanese'
# ['キヌユイ', 'を', '買う', 'と', '必ず', '定期', '縛り', 'に', 'なり', 'ます', 'か', '?', 'それ', 'と', 'も', '自分', 'で', '定期', '購入', 'する', 'の', 'です', 'か', '?']
# ['名詞', '助詞', '動詞', '助詞', '副詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号', '代名詞', '助詞', '助詞', '名詞', '助詞', '名詞', '名詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'はい'
# 'Unknown'
# ['はい']
# ['感動詞']
# --------------------------------
#
# 'マイページ'
# 'Japanese'
# ['マイ', 'ページ']
# ['名詞', '名詞']
# --------------------------------
#
# '配送予定日'
# 'Japanese'
# ['配送', '予定', '日']
# ['名詞', '名詞', '名詞']
# --------------------------------
#
# 'キヌユイタマヌピュアオイルは、敏感肌でもいい？'
# 'Japanese'
# ['キヌユイタマ', 'ヌピュア', 'オイル', 'は', '、', '敏感', '肌', 'で', 'も', 'いい', '?']
# ['名詞', '名詞', '名詞', '助詞', '補助記号', '名詞', '名詞', '助詞', '助詞', '形容詞', '補助記号']
# --------------------------------
#
# '何歳むけですか？'
# 'Japanese'
# ['何', '歳', 'むけ', 'です', 'か', '?']
# ['名詞', '接尾辞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ニキビがちょっとひどくて、キヌユイタマヌピュアオイルは治せますか?'
# 'Japanese'
# ['ニキビ', 'が', 'ちょっと', 'ひどく', 'て', '、', 'キヌユイタマ', 'ヌピュア', 'オイル', 'は', '治せ', 'ます', 'か', '?']
# ['名詞', '助詞', '副詞', '形容詞', '助詞', '補助記号', '名詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ニキビより、毛穴重視ですか？'
# 'Japanese'
# ['ニキビ', 'より', '、', '毛穴', '重視', 'です', 'か', '?']
# ['名詞', '助詞', '補助記号', '名詞', '名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '毎日使用ですか？'
# 'Japanese'
# ['毎日', '使用', 'です', 'か', '?']
# ['名詞', '名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'キヌユイタマヌc25＋と、キヌユイタマヌピュアオイルは何が違うのですか？'
# 'Japanese'
# ['キヌユイタマヌ', 'c', '2', '5', '+', 'と', '、', 'キヌユイタマ', 'ヌピュア', 'オイル', 'は', '何', 'が', '違う', 'の', 'です', 'か', '?']
# ['名詞', '記号', '名詞', '名詞', '補助記号', '助詞', '補助記号', '名詞', '名詞', '名詞', '助詞', '代名詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'タマヌC25＋はニキビと毛穴は治せますか?'
# 'Japanese'
# ['タマヌ', 'C', '2', '5', '+', 'は', 'ニキビ', 'と', '毛穴', 'は', '治せ', 'ます', 'か', '?']
# ['名詞', '名詞', '名詞', '名詞', '補助記号', '助詞', '名詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ありがとうございます'
# 'Japanese'
# ['ありがとう', 'ござい', 'ます']
# ['感動詞', '動詞', '助動詞']
# --------------------------------
#
# 'キヌユイタマヌピュアオイルはピーリングですか？'
# 'Japanese'
# ['キヌユイタマ', 'ヌピュア', 'オイル', 'は', 'ピーリング', 'です', 'か', '?']
# ['名詞', '名詞', '名詞', '助詞', '名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'マイルドピーリング成分は痛いですか？'
# 'Japanese'
# ['マイルド', 'ピーリング', '成分', 'は', '痛い', 'です', 'か', '?']
# ['形状詞', '名詞', '名詞', '助詞', '形容詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '効果はどれぐらいででます？'
# 'Japanese'
# ['効果', 'は', 'どれ', 'ぐらい', 'で', 'で', 'ます', '?']
# ['名詞', '助詞', '代名詞', '助詞', '助動詞', '助動詞', '助動詞', '補助記号']
# --------------------------------
#
# '10代が使ってもいいのですか？'
# 'Japanese'
# ['1', '0', '代', 'が', '使っ', 'て', 'も', 'いい', 'の', 'です', 'か', '?']
# ['名詞', '名詞', '名詞', '助詞', '動詞', '助詞', '助詞', '形容詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '毎日朝と夜で使うのですか？'
# 'Japanese'
# ['毎日', '朝', 'と', '夜', 'で', '使う', 'の', 'です', 'か', '?']
# ['名詞', '名詞', '助詞', '名詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'どこに保存しますか？'
# 'Japanese'
# ['どこ', 'に', '保存', 'し', 'ます', 'か', '?']
# ['代名詞', '助詞', '名詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'これを使い続け、夏も使用すると顔面サラサラですか？'
# 'Japanese'
# ['これ', 'を', '使い', '続け', '、', '夏', 'も', '使用', 'する', 'と', '顔面', 'サラサラ', 'です', 'か', '?']
# ['代名詞', '助詞', '動詞', '動詞', '補助記号', '名詞', '助詞', '名詞', '動詞', '助詞', '名詞', '形状詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '参考になりました。購入前向きで考えたいと思います。'
# 'Japanese'
# ['参考', 'に', 'なり', 'まし', 'た', '。', '購入', '前向き', 'で', '考え', 'たい', 'と', '思い', 'ます', '。']
# ['名詞', '助詞', '動詞', '助動詞', '助動詞', '補助記号', '名詞', '形状詞', '助動詞', '動詞', '助動詞', '助詞', '動詞', '助動詞', '補助記号']
# --------------------------------
#
# '1回だけの購入もできますよね？'
# 'Japanese'
# ['1', '回', 'だけ', 'の', '購入', 'も', 'でき', 'ます', 'よ', 'ね', '?']
# ['名詞', '名詞', '助詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '助詞', '補助記号']
# --------------------------------
#
# 'ご解約の仕方'
# 'Japanese'
# ['ご', '解約', 'の', '仕方']
# ['接頭辞', '名詞', '助詞', '名詞']
# --------------------------------
#
# '初回購入のみで購入した場合、定期購入はないですよね？'
# 'Japanese'
# ['初回', '購入', 'のみ', 'で', '購入', 'し', 'た', '場合', '、', '定期', '購入', 'は', 'ない', 'です', 'よ', 'ね', '?']
# ['名詞', '名詞', '助詞', '助詞', '名詞', '動詞', '助動詞', '名詞', '補助記号', '名詞', '名詞', '助詞', '形容詞', '助動詞', '助詞', '助詞', '補助記号']
# --------------------------------
#
# '初回購入しました。\n↓\n解約手続きをかけるのですか？'
# 'Japanese'
# ['初回', '購入', 'し', 'まし', 'た', '。', '\n', '↓', '\n', '解約', '手続き', 'を', 'かける', 'の', 'です', 'か', '?']
# ['名詞', '名詞', '動詞', '助動詞', '助動詞', '補助記号', '補助記号', '補助記号', '補助記号', '名詞', '名詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ニキビも治る？'
# 'Japanese'
# ['ニキビ', 'も', '治る', '?']
# ['名詞', '助詞', '動詞', '補助記号']
# --------------------------------
#
# '先ほど約 2千円で買えるって書いてあったので買ったのですが合計で一万円になったんですけどこれってキャンセルにできないんですか？'
# 'Japanese'
# ['先ほど', '約', '\u3000', '2千', '円', 'で', '買える', 'って', '書い', 'て', 'あっ', 'た', 'の', 'で', '買っ', 'た', 'の', 'です', 'が', '合計', 'で', '一', '万', '円', 'に', 'なっ', 'た', 'ん', 'です', 'けど', 'これ', 'って', 'キャンセル', 'に', 'でき', 'ない', 'ん', 'です', 'か', '?']
# ['名詞', '接頭辞', '空白', '名詞', '名詞', '助詞', '動詞', '助詞', '動詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '名詞', '助詞', '名詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '代名詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '契約解除したいです'
# 'Japanese'
# ['契約', '解除', 'し', 'たい', 'です']
# ['名詞', '名詞', '動詞', '助動詞', '助動詞']
# --------------------------------
#
# '初めての方は1980円なんですか！？'
# 'Japanese'
# ['初めて', 'の', '方', 'は', '1', '9', '8', '0', '円', 'な', 'ん', 'です', 'か', '!', '?']
# ['副詞', '助詞', '名詞', '助詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号', '補助記号']
# --------------------------------
#
# '使った時はどんな感じですか？'
# 'Japanese'
# ['使っ', 'た', '時', 'は', 'どんな', '感じ', 'です', 'か', '?']
# ['動詞', '助動詞', '名詞', '助詞', '連体詞', '名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '肌は綺麗になりますか？✨'
# 'Japanese'
# ['肌', 'は', '綺麗', 'に', 'なり', 'ます', 'か', '?', '✨']
# ['名詞', '助詞', '形状詞', '助動詞', '動詞', '助動詞', '助詞', '補助記号', '補助記号']
# --------------------------------
#
# 'ありがとうございます！'
# 'Japanese'
# ['ありがとう', 'ござい', 'ます', '!']
# ['感動詞', '動詞', '助動詞', '補助記号']
# --------------------------------
#
# '初めての方は1980円なんですか！？'
# 'Japanese'
# ['初めて', 'の', '方', 'は', '1', '9', '8', '0', '円', 'な', 'ん', 'です', 'か', '!', '?']
# ['副詞', '助詞', '名詞', '助詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号', '補助記号']
# --------------------------------
#
# '解約'
# 'Unknown'
# ['解約']
# ['名詞']
# --------------------------------
#
# 'Dowhite＋'
# 'Unknown'
# ['Dowhite', '+']
# ['名詞', '補助記号']
# --------------------------------
#
# '黄色と白色どっちが良いですか？'
# 'Japanese'
# ['黄色', 'と', '白色', 'どっち', 'が', '良い', 'です', 'か', '?']
# ['名詞', '助詞', '名詞', '代名詞', '助詞', '形容詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '毛穴には効きますか？'
# 'Japanese'
# ['毛穴', 'に', 'は', '効き', 'ます', 'か', '?']
# ['名詞', '助詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ありがとうございます'
# 'Japanese'
# ['ありがとう', 'ござい', 'ます']
# ['感動詞', '動詞', '助動詞']
# --------------------------------
#
# '1'
# 'Unknown'
# ['1']
# ['名詞']
# --------------------------------
#
# 'キャンセルはできる？'
# 'Japanese'
# ['キャンセル', 'は', 'できる', '?']
# ['名詞', '助詞', '動詞', '補助記号']
# --------------------------------
#
# '定期コース'
# 'Japanese'
# ['定期', 'コース']
# ['名詞', '名詞']
# --------------------------------
#
# '定期コース再開したい'
# 'Japanese'
# ['定期', 'コース', '再開', 'し', 'たい']
# ['名詞', '名詞', '名詞', '動詞', '助動詞']
# --------------------------------
#
# '定期コースできない'
# 'Japanese'
# ['定期', 'コース', 'でき', 'ない']
# ['名詞', '名詞', '動詞', '助動詞']
# --------------------------------
#
# 'いらないです'
# 'Japanese'
# ['いら', 'ない', 'です']
# ['動詞', '助動詞', '助動詞']
# --------------------------------
#
# '訴えますよ'
# 'Japanese'
# ['訴え', 'ます', 'よ']
# ['動詞', '助動詞', '助詞']
# --------------------------------
#
# 'あけましておめでとうございます🫶🏻'
# 'Japanese'
# ['あけ', 'まし', 'て', 'お', 'めでとう', 'ござい', 'ます', '🫶', '🏻']
# ['動詞', '助動詞', '助詞', '接頭辞', '形容詞', '動詞', '助動詞', '補助記号', '補助記号']
# --------------------------------
#
# '支払い方法を教えてください'
# 'Japanese'
# ['支払い', '方法', 'を', '教え', 'て', 'ください']
# ['動詞', '名詞', '助詞', '動詞', '助詞', '動詞']
# --------------------------------
#
# '初回のみで解約することはできますか？'
# 'Japanese'
# ['初回', 'のみ', 'で', '解約', 'する', 'こと', 'は', 'でき', 'ます', 'か', '?']
# ['名詞', '助詞', '助詞', '名詞', '動詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ビタミンキヌユイ'
# 'Japanese'
# ['ビタミン', 'キヌユイ']
# ['名詞', '名詞']
# --------------------------------
#
# 'ログイン'
# 'Japanese'
# ['ログ', 'イン']
# ['名詞', '名詞']
# --------------------------------
#
# '1'
# 'Unknown'
# ['1']
# ['名詞']
# --------------------------------
#
# '購入したけど、いつ発送される？'
# 'Japanese'
# ['購入', 'し', 'た', 'けど', '、', 'いつ', '発送', 'さ', 'れる', '?']
# ['名詞', '動詞', '助動詞', '助詞', '補助記号', '代名詞', '名詞', '動詞', '助動詞', '補助記号']
# --------------------------------
#
# 'えー'
# 'Unknown'
# ['えー']
# ['感動詞']
# --------------------------------
#
# '12歳'
# 'Unknown'
# ['1', '2', '歳']
# ['名詞', '名詞', '接尾辞']
# --------------------------------
#
# 'ニキビ'
# 'Japanese'
# ['ニキビ']
# ['名詞']
# --------------------------------
#
# '解約は簡単！といった購入者の動画を沢山見るのですが、その方たちは定期購入を選択しているのですか？'
# 'Japanese'
# ['解約', 'は', '簡単', '!', 'と', 'いっ', 'た', '購入', '者', 'の', '動画', 'を', '沢山', '見る', 'の', 'です', 'が', '、', 'その', '方', 'たち', 'は', '定期', '購入', 'を', '選択', 'し', 'て', 'いる', 'の', 'です', 'か', '?']
# ['名詞', '助詞', '形状詞', '補助記号', '助詞', '動詞', '助動詞', '名詞', '接尾辞', '助詞', '名詞', '助詞', '副詞', '動詞', '助詞', '助動詞', '助詞', '補助記号', '連体詞', '名詞', '接尾辞', '助詞', '名詞', '名詞', '助詞', '名詞', '動詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '解約'
# 'Unknown'
# ['解約']
# ['名詞']
# --------------------------------
#
# '値段'
# 'Unknown'
# ['値段']
# ['名詞']
# --------------------------------
#
# 'どこで買える'
# 'Japanese'
# ['どこ', 'で', '買える']
# ['代名詞', '助詞', '動詞']
# --------------------------------
#
# '買いたい'
# 'Japanese'
# ['買い', 'たい']
# ['動詞', '助動詞']
# --------------------------------
#
# 'タマヌピュアオイルセラムを使用すればいちご鼻は治りますか？'
# 'Japanese'
# ['タマヌピュア', 'オイルセラム', 'を', '使用', 'すれ', 'ば', 'いちご', '鼻', 'は', '治り', 'ます', 'か', '?']
# ['名詞', '名詞', '助詞', '名詞', '動詞', '助詞', '名詞', '接尾辞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'どのような美容成分が入ってますか？'
# 'Japanese'
# ['どの', 'よう', 'な', '美容', '成分', 'が', '入っ', 'て', 'ます', 'か', '?']
# ['連体詞', '形状詞', '助動詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '白玉菌は入ってないのですか？'
# 'Japanese'
# ['白玉', '菌', 'は', '入っ', 'て', 'ない', 'の', 'です', 'か', '?']
# ['名詞', '名詞', '助詞', '動詞', '助動詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '12歳'
# 'Unknown'
# ['1', '2', '歳']
# ['名詞', '名詞', '接尾辞']
# --------------------------------
#
# 'ありがとうございます'
# 'Japanese'
# ['ありがとう', 'ござい', 'ます']
# ['感動詞', '動詞', '助動詞']
# --------------------------------
#
# '安心しました✨'
# 'Japanese'
# ['安心', 'し', 'まし', 'た', '✨']
# ['名詞', '動詞', '助動詞', '助動詞', '補助記号']
# --------------------------------
#
# 'ありがとうございました'
# 'Japanese'
# ['ありがとう', 'ござい', 'まし', 'た']
# ['感動詞', '動詞', '助動詞', '助動詞']
# --------------------------------
#
# '定期じゃなくても、初回限定価格でかえますか？'
# 'Japanese'
# ['定期', 'じゃ', 'なく', 'て', 'も', '、', '初回', '限定', '価格', 'で', 'かえ', 'ます', 'か', '?']
# ['名詞', '助動詞', '形容詞', '助詞', '助詞', '補助記号', '名詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '？？'
# 'Unknown'
# ['?', '?']
# ['補助記号', '補助記号']
# --------------------------------
#
# 'ありがとうございます'
# 'Japanese'
# ['ありがとう', 'ござい', 'ます']
# ['感動詞', '動詞', '助動詞']
# --------------------------------
#
# 'ニキビ'
# 'Japanese'
# ['ニキビ']
# ['名詞']
# --------------------------------
#
# 'マイページ'
# 'Japanese'
# ['マイ', 'ページ']
# ['名詞', '名詞']
# --------------------------------
#
# 'はーい'
# 'Unknown'
# ['はーい']
# ['感動詞']
# --------------------------------
#
# 'どんな効果がある？'
# 'Japanese'
# ['どんな', '効果', 'が', 'ある', '?']
# ['連体詞', '名詞', '助詞', '動詞', '補助記号']
# --------------------------------
#
# 'ねぇ！'
# 'Unknown'
# ['ねぇ', '!']
# ['感動詞', '補助記号']
# --------------------------------
#
# '全然良くなかったんですけど'
# 'Japanese'
# ['全然', '良く', 'なかっ', 'た', 'ん', 'です', 'けど']
# ['副詞', '形容詞', '形容詞', '助動詞', '助詞', '助動詞', '助詞']
# --------------------------------
#
# '嘘でーすごめんなさーい'
# 'Japanese'
# ['嘘', 'で', 'ーす', 'ごめん', 'な', 'さーい']
# ['名詞', '助詞', 'web誤脱', '名詞', '助動詞', 'web誤脱']
# --------------------------------
#
# 'ごめんね'
# 'Japanese'
# ['ごめん', 'ね']
# ['名詞', '助詞']
# --------------------------------
#
# 'ねぇ'
# 'Unknown'
# ['ねぇ']
# ['感動詞']
# --------------------------------
#
# 'あのキヌユイって1980円で買えると書いてあるのに1万と出てきたのですが？(怒る)(怒る)(怒る)(怒る)(怒る)'
# 'Japanese'
# ['あの', 'キヌユイ', 'って', '1', '9', '8', '0', '円', 'で', '買える', 'と', '書い', 'て', 'ある', 'の', 'に', '1', '万', 'と', '出', 'て', 'き', 'た', 'の', 'です', 'が', '?', '(', '怒る', ')', '(', '怒る', ')', '(', '怒る', ')', '(', '怒る', ')', '(', '怒る', ')']
# ['連体詞', '名詞', '助動詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助詞', '動詞', '助詞', '動詞', '助詞', '動詞', '助詞', '助詞', '名詞', '名詞', '助詞', '動詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号', '補助記号', '動詞', '補助記号', '補助記号', '動詞', '補助記号', '補助記号', '動詞', '補助記号', '補助記号', '動詞', '補助記号', '補助記号', '動詞', '補助記号']
# --------------------------------
#
# 'か'
# 'Unknown'
# ['か']
# ['助詞']
# --------------------------------
#
# '定期購入しないでできますか?'
# 'Japanese'
# ['定期', '購入', 'し', 'ない', 'で', 'でき', 'ます', 'か', '?']
# ['名詞', '名詞', '動詞', '助動詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '解約金はでますか?'
# 'Japanese'
# ['解約', '金', 'は', 'で', 'ます', 'か', '?']
# ['名詞', '接尾辞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '解約方法を教えてください'
# 'Japanese'
# ['解約', '方法', 'を', '教え', 'て', 'ください']
# ['名詞', '名詞', '助詞', '動詞', '助詞', '動詞']
# --------------------------------
#
# 'そばかすは消えますか？'
# 'Japanese'
# ['そばかす', 'は', '消え', 'ます', 'か', '?']
# ['名詞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '肌は綺麗になりますか？'
# 'Japanese'
# ['肌', 'は', '綺麗', 'に', 'なり', 'ます', 'か', '?']
# ['名詞', '助詞', '形状詞', '助動詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'キヌユイの初回申し込みをしたのですが、申し込みがしっかりできているのか確認して頂きたいです！'
# 'Japanese'
# ['キヌユイ', 'の', '初回', '申し込み', 'を', 'し', 'た', 'の', 'です', 'が', '、', '申し込み', 'が', 'しっかり', 'でき', 'て', 'いる', 'の', 'か', '確認', 'し', 'て', '頂き', 'たい', 'です', '!']
# ['名詞', '助詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号', '名詞', '助詞', '副詞', '動詞', '助詞', '動詞', '助詞', '助詞', '名詞', '動詞', '助詞', '動詞', '助動詞', '助動詞', '補助記号']
# --------------------------------
#
# 'シミとそばかすは同じですか?'
# 'Japanese'
# ['シミ', 'と', 'そばかす', 'は', '同じ', 'です', 'か', '?']
# ['名詞', '助詞', '名詞', '助詞', '形状詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '17歳からシミができることはないですか?'
# 'Japanese'
# ['1', '7', '歳', 'から', 'シミ', 'が', 'できる', 'こと', 'は', 'ない', 'です', 'か', '?']
# ['名詞', '名詞', '接尾辞', '助詞', '名詞', '助詞', '動詞', '名詞', '助詞', '形容詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'そばかすの可能性が高いですか'
# 'Japanese'
# ['そばかす', 'の', '可能', '性', 'が', '高い', 'です', 'か']
# ['名詞', '助詞', '形状詞', '接尾辞', '助詞', '形容詞', '助動詞', '助詞']
# --------------------------------
#
# '頬に沢山あるのですが'
# 'Japanese'
# ['頬', 'に', '沢山', 'ある', 'の', 'です', 'が']
# ['名詞', '助詞', '副詞', '動詞', '助詞', '助動詞', '助詞']
# --------------------------------
#
# 'ありがとうございました'
# 'Japanese'
# ['ありがとう', 'ござい', 'まし', 'た']
# ['感動詞', '動詞', '助動詞', '助動詞']
# --------------------------------
#
# 'KINUIは肌が弱くても使えますか'
# 'Japanese'
# ['KINUI', 'は', '肌', 'が', '弱く', 'て', 'も', '使え', 'ます', 'か']
# ['名詞', '助詞', '名詞', '助詞', '形容詞', '助詞', '助詞', '動詞', '助動詞', '助詞']
# --------------------------------
#
# '解約'
# 'Unknown'
# ['解約']
# ['名詞']
# --------------------------------
#
# '購入履歴'
# 'Japanese'
# ['購入', '履歴']
# ['名詞', '名詞']
# --------------------------------
#
# '何日後に届きますか？'
# 'Japanese'
# ['何', '日', '後', 'に', '届き', 'ます', 'か', '?']
# ['名詞', '名詞', '接尾辞', '助詞', '動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '値段はいくらですか？'
# 'Japanese'
# ['値段', 'は', 'いくら', 'です', 'か', '?']
# ['名詞', '助詞', '名詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'ドンキで売ってますか?'
# 'Japanese'
# ['ドンキ', 'で', '売っ', 'て', 'ます', 'か', '?']
# ['名詞', '助詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '良くないという口コミもあるようですが💦'
# 'Japanese'
# ['良く', 'ない', 'と', 'いう', '口コミ', 'も', 'ある', 'よう', 'です', 'が', '💦']
# ['形容詞', '形容詞', '助詞', '動詞', '名詞', '助詞', '動詞', '形状詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '買ってみたので使ってみたいと思います。'
# 'Japanese'
# ['買っ', 'て', 'み', 'た', 'の', 'で', '使っ', 'て', 'み', 'たい', 'と', '思い', 'ます', '。']
# ['動詞', '助詞', '動詞', '助動詞', '助詞', '助動詞', '動詞', '助詞', '動詞', '助動詞', '助詞', '動詞', '助動詞', '補助記号']
# --------------------------------
#
# 'かいたい'
# 'Japanese'
# ['かいたい']
# ['名詞']
# --------------------------------
#
# '解約'
# 'Unknown'
# ['解約']
# ['名詞']
# --------------------------------
#
# 'チェック'
# 'Japanese'
# ['チェック']
# ['名詞']
# --------------------------------
#
# '次回スキップしたいです。'
# 'Japanese'
# ['次回', 'スキップ', 'し', 'たい', 'です', '。']
# ['名詞', '名詞', '動詞', '助動詞', '助動詞', '補助記号']
# --------------------------------
#
# '診断スタート▷'
# 'Japanese'
# ['診断', 'スタート', '▷']
# ['名詞', '名詞', '補助記号']
# --------------------------------
#
# '本当はいくらなんですか？'
# 'Japanese'
# ['本当', 'は', 'いくら', 'な', 'ん', 'です', 'か', '?']
# ['名詞', '助詞', '名詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'キヌユイはどのタイミングで塗るのが正解？'
# 'Japanese'
# ['キヌユイ', 'は', 'どの', 'タイミング', 'で', '塗る', 'の', 'が', '正解', '?']
# ['名詞', '助詞', '連体詞', '名詞', '助詞', '動詞', '助詞', '助詞', '名詞', '補助記号']
# --------------------------------
#
# 'お風呂の時にすればいい？'
# 'Japanese'
# ['お', '風呂', 'の', '時', 'に', 'すれ', 'ば', 'いい', '?']
# ['接頭辞', '名詞', '助詞', '名詞', '助詞', '動詞', '助詞', '形容詞', '補助記号']
# --------------------------------
#
# '停止したい'
# 'Japanese'
# ['停止', 'し', 'たい']
# ['名詞', '動詞', '助動詞']
# --------------------------------
#
# '詳しく'
# 'Japanese'
# ['詳しく']
# ['形容詞']
# --------------------------------
#
# 'は'
# 'Unknown'
# ['は']
# ['助詞']
# --------------------------------
#
# 'うーん'
# 'Unknown'
# ['うーん']
# ['感動詞']
# --------------------------------
#
# 'メールアドレスが使われているとでるのですが、どうすればいいでしょうか？'
# 'Japanese'
# ['メール', 'アドレス', 'が', '使わ', 'れ', 'て', 'いる', 'と', 'でる', 'の', 'です', 'が', '、', 'どう', 'すれ', 'ば', 'いい', 'でしょう', 'か', '?']
# ['名詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '動詞', '助詞', '動詞', '助詞', '助動詞', '助詞', '補助記号', '副詞', '動詞', '助詞', '形容詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# 'マイページ'
# 'Japanese'
# ['マイ', 'ページ']
# ['名詞', '名詞']
# --------------------------------
#
# 'みんな解約してね！って言ってるんですが、、定期購入じゃないのを選べるんじゃないんですか？？'
# 'Japanese'
# ['みんな', '解約', 'し', 'て', 'ね', '!', 'って', '言っ', 'てる', 'ん', 'です', 'が', '、', '、', '定期', '購入', 'じゃ', 'ない', 'の', 'を', '選べる', 'ん', 'じゃ', 'ない', 'ん', 'です', 'か', '?', '?']
# ['名詞', '名詞', '動詞', '助詞', '助詞', '補助記号', '助詞', '動詞', '助動詞', '助詞', '助動詞', '助詞', '補助記号', '補助記号', '名詞', '名詞', '助動詞', '形容詞', '助詞', '助詞', '動詞', '助詞', '助動詞', '形容詞', '助詞', '助動詞', '助詞', '補助記号', '補助記号']
# --------------------------------
#
# '荷物がなかなか発送されない'
# 'Japanese'
# ['荷物', 'が', 'なかなか', '発送', 'さ', 'れ', 'ない']
# ['名詞', '助詞', '副詞', '名詞', '動詞', '助動詞', '助動詞']
# --------------------------------
#
# '店頭にはないですか？'
# 'Japanese'
# ['店頭', 'に', 'は', 'ない', 'です', 'か', '?']
# ['名詞', '助詞', '助詞', '形容詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '楽天とかでは1980円で買えないですか？'
# 'Japanese'
# ['楽天', 'と', 'か', 'で', 'は', '1', '9', '8', '0', '円', 'で', '買え', 'ない', 'です', 'か', '?']
# ['名詞', '助詞', '助詞', '助詞', '助詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '定期コースじゃないと1980円で買えないですか？'
# 'Japanese'
# ['定期', 'コース', 'じゃ', 'ない', 'と', '1', '9', '8', '0', '円', 'で', '買え', 'ない', 'です', 'か', '?']
# ['名詞', '名詞', '助動詞', '形容詞', '助詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助詞', '動詞', '助動詞', '助動詞', '助詞', '補助記号']
# --------------------------------
#
# '定期の解約の仕方は？'
# 'Japanese'
# ['定期', 'の', '解約', 'の', '仕方', 'は', '?']
# ['名詞', '助詞', '名詞', '助詞', '名詞', '助詞', '補助記号']
# --------------------------------

# %% [markdown]
# ### English language (Pt 1)

# %%
import spacy

# %%
#python -m spacy download en_core_web_lg
#python -m spacy download en_core_web_sm

# %%
nlp = spacy.load("en_core_web_lg")

# %%
text = "Tesla Inc is going to acquire Twitter for $45 billion"
doc = nlp(text)

entities = doc.ents
#for ent in entities:
#    print(ent)

#for ent in entities:
#    print(ent.text)

for ent in entities:
    print(ent.text, '|', ent.label_)
# Out:
# Tesla Inc | ORG
# Twitter | ORG
# $45 billion | MONEY

# %%
def ner_en_spacy(text):

    doc = nlp(text)
    entities = doc.ents

    all_entities = []

    for ent in entities:
        all_entities.append([ent.text, ent.label_])
    return(all_entities)

# %% [markdown]
# ### Pt 2

# %%
from flair.data import Sentence
from flair.nn import Classifier

# %%
# make a sentence
sentence = Sentence('I love Berlin .')

# load the NER tagger
tagger_ner = Classifier.load('ner')

# run NER over sentence
tagger_ner.predict(sentence)

# print the sentence with all annotations
print(sentence)
# Out:
# 2025-01-12 00:00:12,089 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# Sentence[4]: "I love Berlin ." → ["Berlin"/LOC]

# %%
sentence.get_label().labeled_identifier
# Out:
# 'Span[2:3]: "Berlin"/LOC'

# %%
# Print the entities
all_entities = []
print("Extracted Entities:")
for entity in sentence.get_spans('ner'):
    print(f"Entity: {entity.text}, Type: {entity.tag}, Confidence: {entity.score:.2f}")
    all_entities.append([entity.text, entity.tag, entity.score])
# Out:
# Extracted Entities:
# Entity: Berlin, Type: LOC, Confidence: 1.00

# %%
def ner_en(text):
    # make a sentence
    sentence = Sentence(text)

    # load the NER tagger
    tagger_ner = Classifier.load('ner')

    # run NER over sentence
    tagger_ner.predict(sentence)

    all_entities = []
    for entity in sentence.get_spans('ner'):
        all_entities.append([entity.text, entity.tag, entity.score])

    return(all_entities)

# %%
# make a sentence
sentence = Sentence('I love Berlin .')

# load the NER tagger
tagger_ner = Classifier.load('ner-fast')

# run NER over sentence
tagger_ner.predict(sentence)

# print the sentence with all annotations
print(sentence)
# Out:
# 2025-01-12 00:00:15,260 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# Sentence[4]: "I love Berlin ." → ["Berlin"/LOC]

# %%
# Print the entities
print("Extracted Entities:")
for entity in sentence.get_spans('ner'):
    print(f"Entity: {entity.text}, Type: {entity.tag}, Confidence: {entity.score:.2f}")
# Out:
# Extracted Entities:
# Entity: Berlin, Type: LOC, Confidence: 1.00

# %%
# make a sentence
sentence = Sentence('I love Berlin .')

# load the NER tagger
tagger = Classifier.load('sentiment')

# run NER over sentence
tagger.predict(sentence)

# print the sentence with all annotations
print(sentence)
# Out:
# Sentence[4]: "I love Berlin ." → POSITIVE (0.9983)

# %% [markdown]
# ### Example 2

# %%
#path = '/home/luis-carlos/Documents/experiments/nlp/data/synthetic_reviews_laptops.csv'
path = '/home/luis-carlos/Documents/experiments/nlp/data/synthetic_reviews_laptops_v2.csv'

data = pd.read_csv(path)
data.head()
# Out:
#                                             question language
# 0           What is the battery life of this laptop?       en
# 1  Does this laptop come with pre-installed softw...       en
# 2  Is the RAM upgradeable? If yes, what is the ma...       en
# 3      What type of processor does this laptop have?       en
# 4   Does this laptop have a dedicated graphics card?       en

# %%
all_info_lt = []

for index, row in data.iterrows():
    text = row['question']
#    pprint(text)

    # Inferring language
    isReliable, textBytesFound, details = cld2.detect(text)

    detected_language = details[0][0]
#    pprint(detected_language)

    if detected_language == 'Japanese':
        # Starting NER
        words = nagisa.tagging(text)
#        print(words.words)
#        print(words.postags)
        all_info_lt.append([text, words.words, words.postags])
    elif detected_language == 'ENGLISH':
        doc = nlp(text)
        entities = doc.ents
#        for ent in entities:
#            print(ent.text, '|', ent.label_)

        all_info_lt.append([text, entities])

# %%
all_info_lt[30]
# Out:
# ['ノートパソコンの重量はどれくらいですか？持ち運びに便利ですか？',
#  ['ノート',
#   'パソコン',
#   'の',
#   '重量',
#   'は',
#   'どれ',
#   'くらい',
#   'です',
#   'か',
#   '?',
#   '持ち運び',
#   'に',
#   '便利',
#   'です',
#   'か',
#   '?'],
#  ['名詞',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助詞',
#   '代名詞',
#   '助詞',
#   '助動詞',
#   '助詞',
#   '補助記号',
#   '名詞',
#   '助詞',
#   '名詞',
#   '助動詞',
#   '助詞',
#   '補助記号']]

# %% [markdown]
# ## Final functions

# %%
# Language
# lang_detected(text)

# NER (JP)
# ner_jp_nagisa(text)

# NER (EN)
# ner_en(text)
# ner_en_spacy(text)

# %%
all_info_lt = []

for index, row in data.iterrows():
    text = row['question']

    detected_language = lang_detected(text)[0]

    if detected_language == 'Japanese':        
        all_info_lt.append([{'text': text, 'language': 'japanese', 'ner': ner_jp_nagisa(text)}])
    elif detected_language == 'ENGLISH':
        all_info_lt.append([{'text': text, 'language': 'english', 'ner': ner_en(text), 'ner_spacy': ner_en_spacy(text)}])
# Out:
# 2025-01-12 00:01:36,137 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:39,040 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:42,328 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:45,609 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:48,571 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:52,011 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:55,258 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:01:58,442 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:01,877 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:04,461 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:07,013 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:09,937 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:13,062 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:16,177 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:19,119 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:21,882 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:25,129 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:28,164 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:33,847 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 2025-01-12 00:02:38,428 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>

# %%
print(all_info_lt[30])
# Out:
# [{'text': 'ノートパソコンの重量はどれくらいですか？持ち運びに便利ですか？', 'language': 'japanese', 'ner': (['ノート', 'パソコン', 'の', '重量', 'は', 'どれ', 'くらい', 'です', 'か', '?', '持ち運び', 'に', '便利', 'です', 'か', '?'], ['名詞', '名詞', '助詞', '名詞', '助詞', '代名詞', '助詞', '助動詞', '助詞', '補助記号', '名詞', '助詞', '名詞', '助動詞', '助詞', '補助記号'])}]

# %%
print(all_info_lt[5])
# Out:
# [{'text': 'Is the keyboard backlit?', 'language': 'english', 'ner': [], 'ner_spacy': []}]
